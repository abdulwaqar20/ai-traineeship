# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
pd.__version__
# Out:
# '3.0.3'

# %%
np.__version__
# Out:
# '2.4.6'

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
matplotlib.__version__
# Out:
# '3.11.0'
